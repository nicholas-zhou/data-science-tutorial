# %% [markdown]
# # Reasons for Immigration: Economic Opportunity

# %% [markdown]
# Tutorial by Alex Heng and Nicholas Zhou

# %% [markdown]
# ## Table of Contents
# * [Introduction](#Introduction)
# * [Context](#Context)
# * [Setup](#Setup)
# * [Data Collection](#Data-Collection)
# * [Data Tidying](#Data-Tidying)
#     * [Consistent Countries](#Consistent-Countries)
#     * [Consistent Names](#Consistent-Names)
#     * [Merging DataFrames](#Merging-DataFrames)
#     * [Missing Data](#Missing-Data)
#     * [Getting Accurate Names](#Getting-Accurate-Names)
#     * [Abbreviations](#Abbreviations)
# * [Exploratory Data Analysis and Data Visualization](#Exploratory-Data-Analysis-and-Data-Visualization)
#     * [Scatter Plots](#Scatter-Plots)
#     * [Initial Thoughts from Plots](#Initial-Thoughts-from-Plots)
# * [Hypothesis Testing](#Hypothesis-Testing)
#     * [2013](#2013)
#     * [2014](#2014)
#     * [2015](#2015)
# * [Insights and Final Thoughts](#Insights-and-Final-Thoughts)
#     * [Recap](#Recap)
#     * [Conclusion](#Conclusion)
#     * [Things to Consider](#Things-to-Consider)
# * [Additional Resources](#Additional-Resources)

# %% [markdown]
# ## Introduction
# This is a tutorial that walks through the steps of the data lifecycle: data collection, data processing, exploratory analysis & data visualization, hypothesis testing & machine learning, and insight & policy decision. In data science, it is very important to understand data, process it, extract value from it, visualize it, and communicate it. Hopefully by the end of the tutorial, you walk away with a full understanding of the lifecycle and how to apply it!

# %% [markdown]
# ## Context
#
# There are people who try to argue that the United States has more immigrants originating from poorer countries rather than wealthier countries. We wanted to test whether or not this is true using the different steps of the data lifecycle. Looking at the GDP per capita between 2013 and 2015 for different countries, as well as their number of immigrants (to the United States), we can test the validity of this argument.
#
# There is also another argument that the US should accept immigrants from more developed countries since their citizens are seen as more "desirable" compared to those from underdeveloped countries. With this argument comes the question "why would someone decide to immigrate from a developed country to the United States?". While there are many reasons for someone to immigrate, one of the most common reasons, especially in the United States, is for economic opprortunity. We decided to see the correlation between the national origin of immigrants to the United States and the economic opprotunity of those immigrants' home country (which we decided to measure by GDP per capita).

# %% [markdown]
# ## Setup
# Before we begin, we should to import some packages that will be used for this tutorial.
# 1. Pandas: used to load the data and create the DataFrames
# 2. Matplotlib: used for plots
# 3. NumPy: used to plot regression line
# 4. statsmodels: used for linear regression testing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %% [markdown]
# ## Data Collection

# %% [markdown]
# Of course, we want to start by loading in the data. There is a lot of data on the internet available for us to use.
#
# The data set for GDP per capita that we used can be found from [Our World in Data](https://ourworldindata.org/economic-growth). The data can be found under the "Catch up growth can be fast" section. If you click DOWNLOAD on the chart to the right of the section, you can download the file as a CSV. In addition to the data set, this website has a lot of great information on the history of economic growth if you are interested in reading more about it.
#
# We also decided on using data from [Data.world](https://data.world/rflprr/us-immigration-statistics-15) for number of immigrants. The website requires an account to access the data, but once you create one, you will be able to download the file dhs.xlsx. Notice the file has an Excel sheet extension. To convert that to a CSV (Comma-Separated Values) file, open it and go to Table3 at the bottom (it should be the page with Region of birth in cell A1). Then navigate to File -> Export -> Change File Type -> CSV. A popup will tell you that you cannot export multiple sheets. You can click OK and it will only save Table3, which is all we need.
#
# Two other sources we considered were [The Department of Homeland Security](https://www.dhs.gov/profiles-lawful-permanent-residents) and [Migration Policy Institute](https://www.migrationpolicy.org/programs/data-hub/us-immigration-trends#source). While the DHS would have been a great source to get immigration numbers, we decided against it because the data for different years were separated into different files. We also could not use the Migration Policy Institute's data because the Excel sheet was formatted, so we could not convert to a CSV file.
#
# Now that we have the data files, we can bring them into our notebook. Pandas has a function that allows us to read straight from a CSV file and put that data into a DataFrame. DataFrames are two-dimensional data structures similar to SQL tables or spreadsheet data representations. The two CSV files should be in the same folder as the notebook.

# %%
# use pandas to read the data
gdp_data = pd.read_csv("gdp-per-capita-maddison-2020.csv")

# allows us to get a preview of the DataFrame
gdp_data
# Out:
#             Entity Code  Year  GDP per capita 145446-annotations
# 0      Afghanistan  AFG  1950         1156.00                NaN
# 1      Afghanistan  AFG  1951         1170.00                NaN
# 2      Afghanistan  AFG  1952         1189.00                NaN
# 3      Afghanistan  AFG  1953         1240.00                NaN
# 4      Afghanistan  AFG  1954         1245.00                NaN
# ...            ...  ...   ...             ...                ...
# 19873     Zimbabwe  ZWE  2014         1594.00                NaN
# 19874     Zimbabwe  ZWE  2015         1560.00                NaN
# 19875     Zimbabwe  ZWE  2016         1534.00                NaN
# 19876     Zimbabwe  ZWE  2017         1582.37                NaN
# 19877     Zimbabwe  ZWE  2018         1611.41                NaN
#
# [19878 rows x 5 columns]

# %%
# use pandas to read the data
immigration_data = pd.read_csv("dhs.csv")

# preview DataFrame
immigration_data
# Out:
#           Region of birth     2013       2014       2015
# 0                   Total  990,553  1,016,518  1,051,031
# 1                  Africa   98,304     98,413    101,415
# 2                    Asia  400,548    430,508    419,297
# 3                  Europe   86,556     83,266     85,803
# 4           North America  315,660    324,354    366,126
# ..                    ...      ...        ...        ...
# 213                 Yemen    3,532      3,492      3,194
# 214                Zambia      505        441        460
# 215              Zimbabwe      924        797        779
# 216  All other countries2       27         31         34
# 217               Unknown    3,263      1,150        677
#
# [218 rows x 4 columns]

# %% [markdown]
# This is a great start! We now have GDP per capita  and number of immigrants for countries during the years we wanted.

# %% [markdown]
# ## Data Tidying

# %% [markdown]
# Next, we should tidy up the data so it's easier to work with. Before we can merge the two DataFrames, we should make sure that all the countries show up in both DataFrames.

# %%
# gets all the unique elements in the 'Entity' column
gdp_counts = gdp_data['Entity'].unique()
print("Unique entities in GDP data: " + str(len(gdp_counts)))

# gets all the unique elements in the 'Region of birth' column
imm_counts = immigration_data['Region of birth'].unique()
print("Unique regions in immigration data: " + str(len(imm_counts)))
# Out:
# Unique entities in GDP data: 178
# Unique regions in immigration data: 216

# %% [markdown]
# ### Consistent Countries
# As you can see, the two DataFrames don't even contain the same number of unique entries. Because of this, we did all the work and found all the countries we should remove from each DataFrame. Let's start with the GDP per capita set. Below are the entries from the 'Entity' column that we want to remove from the GDP per capita set.
#
# **Regions**<br>
# * East Asia
# * Eastern Europe
# * Latin America
# * Middle East
# * South and South-East Asia
# * Sub-Sahara Africa
# * Western Europe
# * Western Offshoots
# * World
#
# **Not Recognized**<br>
# * Puerto Rico
#
# **Former Countries**<br>
# * Former USSR
# * Former Yugoslavia
#
# **Not in Immigration Data**<br>
# * Palestine
#
# **United States**<br>
# * United States (we're not going to need the GDP/number of immigrants for the US)

# %% [markdown]
# Pandas has a function to drop a row from the DataFrame. First we need a list of entries that should be removed. Then we can traverse the rows of the entire DataFrame and remove those that have the same 'Entity' names as one of the entries in the list.

# %%
# list of entries to remove
rows_to_drop = ['East Asia', 'Eastern Europe', 'Latin America', 'Middle East', 'South and South-East Asia', \
               'Sub-Sahara Africa', 'Western Europe', 'Western Offshoots', 'World', 'Puerto Rico', \
               'Former USSR', 'Former Yugoslavia', 'United States', 'Palestine']

# for every row in gdp_data
for i in range(0, len(gdp_data)):
    # if the value in the 'Entity' column can be found in the above list
    if gdp_data.loc[i].at["Entity"] in rows_to_drop:
        # remove it from the list
        gdp_data = gdp_data.drop(i)
        
gdp_data
# Out:
#             Entity Code  Year  GDP per capita 145446-annotations
# 0      Afghanistan  AFG  1950         1156.00                NaN
# 1      Afghanistan  AFG  1951         1170.00                NaN
# 2      Afghanistan  AFG  1952         1189.00                NaN
# 3      Afghanistan  AFG  1953         1240.00                NaN
# 4      Afghanistan  AFG  1954         1245.00                NaN
# ...            ...  ...   ...             ...                ...
# 19873     Zimbabwe  ZWE  2014         1594.00                NaN
# 19874     Zimbabwe  ZWE  2015         1560.00                NaN
# 19875     Zimbabwe  ZWE  2016         1534.00                NaN
# 19876     Zimbabwe  ZWE  2017         1582.37                NaN
# 19877     Zimbabwe  ZWE  2018         1611.41                NaN
#
# [19118 rows x 5 columns]

# %% [markdown]
# For the immigration dataset, we'll be removing a lot more, since there were more unique entries in this set to begin with. Below are the entries in the 'Region of birth' column we would like to remove.
#
# **Regions/Misc**<br>
# * Total
# * Africa
# * Asia
# * Europe
# * North America
# * Oceania
# * South America
# * Unknown
# * Country of birth
# * All other countries2
#
# **Not in GDP per Capita Data**<br>
# * American Samoa
# * Anguilla
# * Antigua-Barbuda
# * Aruba
# * Bahamas
# * Belize
# * Bermuda
# * Bhutan
# * British Virgin Islands
# * Brunei
# * Cayman Islands
# * Curacao
# * Eritrea
# * Fiji
# * French Polynesia
# * Grenada
# * Guyana
# * Kiribati
# * Kosovo
# * Macau
# * Maldives
# * Palau
# * Marshall Islands
# * Micronesia, Federated States
# * Monaco
# * Montserrat
# * New Caledonia
# * Papua New Guinea
# * Saint Kitts-Nevis
# * Saint Vincent and the Grenadines
# * Samoa
# * Sint Maarten
# * Solomon Islands
# * Somalia
# * South Sudan
# * Suriname
# * Tonga
# * Turks and Caicos Islands
#
# **Former Countries**<br>
# * Netherlands Antilles (former)
# * Serbia and Montenegro (former)
# * Soviet Union (former)
#
# **United States**<br>
# * United States (we're not going to need the GDP/number of immigrants for the US)

# %%
# list of regions to remove
drop_rows = ['Total', 'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America', 'Unknown', \
            'Country of birth', 'American Samoa', 'Anguilla', 'Antigua-Barbuda', 'Aruba', 'Bahamas', 'Belize', 'Bermuda', \
            'Bhutan', 'British Virgin Islands', 'Brunei', 'Cayman Islands', 'Curacao', 'Eritrea', 'Fiji', \
            'French Polynesia', 'Grenada', 'Guyana', 'Kiribati', 'Kosovo', 'Macau', 'Maldives', 'Palau', \
            'Marshall Islands', 'Micronesia, Federated States', 'Monaco', 'Montserrat', 'Netherlands Antilles (former)', \
            'New Caledonia', 'Papua New Guinea', 'Saint Kitts-Nevis', 'Saint Vincent and the Grenadines', 'Samoa', \
            'Serbia and Montenegro (former)', 'Sint Maarten', 'Solomon Islands', 'Somalia', 'South Sudan', \
            'Soviet Union (former)', 'Suriname', 'Tonga', 'Turks and Caicos Islands', 'All other countries2', \
            'United States']

# actually remove (same method as before)
for i in range(0, len(immigration_data)):
    if immigration_data.loc[i].at['Region of birth'] in drop_rows:
        immigration_data = immigration_data.drop(i)

# %% [markdown]
# Now let's make sure we lined them up correctly.

# %%
gdp_counts = gdp_data['Entity'].unique()
print("Unique entities in GDP data: " + str(len(gdp_counts)))

imm_counts = immigration_data['Region of birth'].unique()
print("Unique regions in immigration data: " + str(len(imm_counts)))
# Out:
# Unique entities in GDP data: 164
# Unique regions in immigration data: 164

# %% [markdown]
# ### Consistent Names
# In addition to not including all the same countries, there were also a few countries that had different names in the two datasets. We will have to standardize those.

# %%
# show the names in GDP data
print("Names in GDP per capita data:")
print(" ")
for i in gdp_counts:
    if i not in imm_counts:
        print(i)
        
print("\n***\n")

print("Names in immigration data:")
print(" ")
# show the names in immigration data
for j in imm_counts:
    if j not in gdp_counts:
        print(j)
# Out:
# Names in GDP per capita data:
#
# Bosnia and Herzegovina
# China
# Congo
# Czechia
# Czechoslovakia
# Democratic Republic of Congo
# Eswatini
# Myanmar
# North Korea
# North Macedonia
# South Korea
#
# ***
#
# Names in immigration data:
#
# Bosnia-Herzegovina
# Burma
# China, People's Republic
# Congo, Democratic Republic
# Congo, Republic
# Czech Republic
# Czechoslovakia (former)
# Korea, North
# Korea, South1
# Macedonia
# Swaziland

# %% [markdown]
# Since we are looking at three years, it would be easier to work with the data if each column contained data for that year. For that reason, we will be merging the GDP per capita data into the immigration DataFrame. However, the names of the countries above are the more standard ones today (i.e. Myanmar is former Burma), we want to change the names in the immigration DataFrame to match the ones in the GDP per capita DataFrame.
#
# In order to do this, we can usea  dictionary to map the old names (from the immigration DataFrame) to new names (from the GDP per capita DataFrame). Then, we will go through every 'Region of birth' entry in the immigration DataFrame, and update it if it has the same name as one of the key values in the dictionary.

# %%
# dictionary of immigration data names
mapping = {
    "Bosnia-Herzegovina": "Bosnia and Herzegovina",
    "Burma": "Myanmar",
    "China, People\'s Republic": "China",
    "Congo, Democratic Republic": "Democratic Republic of Congo",
    "Congo, Republic": "Congo", 
    "Czech Republic": "Czechia",
    "Czechoslovakia (former)": "Czechoslovakia", 
    "Korea, North": "North Korea",
    "Korea, South1":"South Korea",
    "Macedonia": "North Macedonia",
    "Swaziland": "Eswatini"
}

# for every country in immigration data
for i in immigration_data['Region of birth']:
    # if it is found in the mapping dictionary
    if i in mapping:
        # update it
        immigration_data.at[immigration_data[immigration_data['Region of birth'] == i].index[0], 'Region of birth']\
        = mapping[i]

# %% [markdown]
# ### Merging DataFrames
# Now we can finally merge the GDP per capita DataFrame into the immigration DataFrame. To do this, we create three new columns in our immigration DataFrame (one for each year). The columns will consist of the GDP per capita for that row's country according to the GDP per capita DataFrame.

# %%
for year in range(2013,2016):
    # empty list
    arr = []
    # for every entry in region of birth
    for i in immigration_data['Region of birth']:
        # add the corresponding GDP per capita for that country during that year
        arr.append(gdp_data.loc[gdp_data['Entity'] == i].loc[gdp_data['Year'] == year]['GDP per capita'].tolist()[0])
    # create a new column in the DataFrame using the list
    immigration_data[str(year) + ' GDP per capita'] = arr
    
immigration_data
# Out:
#     Region of birth    2013    2014    2015  2013 GDP per capita  \
# 10      Afghanistan   2,196  10,527   8,328               2025.0
# 11          Albania   3,186   3,828   4,653               9660.0
# 12          Algeria   1,241   1,669   1,775              13494.0
# 14           Angola     143     148     154               8508.0
# 17        Argentina   4,372   3,874   3,730              19873.0
# ..              ...     ...     ...     ...                  ...
# 211       Venezuela   9,572   8,427   9,144              21429.0
# 212         Vietnam  27,101  30,283  30,832               5200.0
# 213           Yemen   3,532   3,492   3,194               4165.0
# 214          Zambia     505     441     460               3419.0
# 215        Zimbabwe     924     797     779               1604.0
#
#      2014 GDP per capita  2015 GDP per capita
# 10                2022.0               1928.0
# 11                9808.0              10032.0
# 12               13744.0              14004.0
# 14                8673.0               8689.0
# 17               19183.0              19502.0
# ..                   ...                  ...
# 211              20317.0              18802.0
# 212               5455.0               5763.0
# 213               4054.0               2844.0
# 214               3478.0               3478.0
# 215               1594.0               1560.0
#
# [164 rows x 7 columns]

# %% [markdown]
# ### Missing Data
# We noticed that for the 2013 column, Comoros had a number of immigrants of "D". Based on the low immigration numbers from Comoros in 2014 and 2015, we inferred that "D" was a substitute value for none. Since we want to be able to convert the values to integers, we will have to address this one value. There are a couple options: remove the row or encode the missing data. We decided it would be best to encode the data and change it to 0. This is because Comoros has data for 2014 and 2015, so we do not want to remove it entirely. Additionally, its immigration numbers for 2014 and 2015 are pretty low, so it could factor into how few people immigration from this country.

# %%
# encode to 0
immigration_data.at[immigration_data[immigration_data['Region of birth'] == 'Comoros'].index[0], '2013'] = '0'

# for every entry in the 2013, 2014, and 2015 columns
for year in ['2013', '2014', '2015']:
    arr = []
    for i in immigration_data[year]:
        # remove commas and convert to integer
        arr.append(int(i.replace(',', '')))
    immigration_data[year] = arr

# %% [markdown]
# ### Getting Accurate Names
# Now that we have columns for GDP per capita and number of immigrants, we want to specify the names of the 2013, 2014, and 2015 columns to avoid confusion. Pandas makes it easy to rename your columns, either with the columns function or rename function. We chose to use columns, simply because it does not require any mapping of values. The new names will be num_Im_*year*.

# %%
# rename
immigration_data.columns = ['Region of birth', 'num_Im_2013', 'num_Im_2014', 'num_Im_2015', \
                           'gdp_2013', 'gdp_2014', 'gdp_2015']

immigration_data
# Out:
#     Region of birth  num_Im_2013  num_Im_2014  num_Im_2015  gdp_2013  \
# 10      Afghanistan         2196        10527         8328    2025.0
# 11          Albania         3186         3828         4653    9660.0
# 12          Algeria         1241         1669         1775   13494.0
# 14           Angola          143          148          154    8508.0
# 17        Argentina         4372         3874         3730   19873.0
# ..              ...          ...          ...          ...       ...
# 211       Venezuela         9572         8427         9144   21429.0
# 212         Vietnam        27101        30283        30832    5200.0
# 213           Yemen         3532         3492         3194    4165.0
# 214          Zambia          505          441          460    3419.0
# 215        Zimbabwe          924          797          779    1604.0
#
#      gdp_2014  gdp_2015
# 10     2022.0    1928.0
# 11     9808.0   10032.0
# 12    13744.0   14004.0
# 14     8673.0    8689.0
# 17    19183.0   19502.0
# ..        ...       ...
# 211   20317.0   18802.0
# 212    5455.0    5763.0
# 213    4054.0    2844.0
# 214    3478.0    3478.0
# 215    1594.0    1560.0
#
# [164 rows x 7 columns]

# %% [markdown]
# ### Abbreviations
# The last thing we want to do before we begin EDA and Data Visualization is create a new column for the abbreviations of the countries. This will be useful later when we begin labeling our plots.

# %%
# empty list
arr = []
# for every entry in region of birth
for i in immigration_data['Region of birth']:
    # add the corresponding abbreviation from GDP DataFrame
    # the codes should be the same every year, we just chose 2014 because we needed to specify a certain row
    arr.append(gdp_data.loc[gdp_data['Entity'] == i].loc[gdp_data['Year'] == 2014]['Code'].tolist()[0])
# create a new column in the DataFrame using the list
immigration_data['Abbreviation'] = arr

immigration_data
# Out:
#     Region of birth  num_Im_2013  num_Im_2014  num_Im_2015  gdp_2013  \
# 10      Afghanistan         2196        10527         8328    2025.0
# 11          Albania         3186         3828         4653    9660.0
# 12          Algeria         1241         1669         1775   13494.0
# 14           Angola          143          148          154    8508.0
# 17        Argentina         4372         3874         3730   19873.0
# ..              ...          ...          ...          ...       ...
# 211       Venezuela         9572         8427         9144   21429.0
# 212         Vietnam        27101        30283        30832    5200.0
# 213           Yemen         3532         3492         3194    4165.0
# 214          Zambia          505          441          460    3419.0
# 215        Zimbabwe          924          797          779    1604.0
#
#      gdp_2014  gdp_2015 Abbreviation
# 10     2022.0    1928.0          AFG
# 11     9808.0   10032.0          ALB
# 12    13744.0   14004.0          DZA
# 14     8673.0    8689.0          AGO
# 17    19183.0   19502.0          ARG
# ..        ...       ...          ...
# 211   20317.0   18802.0          VEN
# 212    5455.0    5763.0          VNM
# 213    4054.0    2844.0          YEM
# 214    3478.0    3478.0          ZMB
# 215    1594.0    1560.0          ZWE
#
# [164 rows x 8 columns]

# %% [markdown]
# ## Exploratory Data Analysis and Data Visualization

# %% [markdown]
# Exploratory Data Analysis is the process of finding patterns and the main characteristics of a dataset in order to begin making hypotheses about the data. It is very useful to do this along with Data Visualization because plots and graphs allow you to visualize the patterns. We have a few different options for how we want to visualize the data. The first one to consider is making line graphs for the GDP per capita for each country. However, this would not really show us anything significant, because we cannot see how the GDP per capita affects the number of immigrants.

# %% [markdown]
# ### Scatter Plots
# Another option is to use scatter plots of GDP per capita vs number of immigrants for every year. This is much better, since we have both pieces of data that we are looking at in the plots. We can also plot a regression line to see if we can find any patterns in the three scatter plots. Pandas has plotting functions and the regression lines will be added using NumPy.

# %%
# plot 2013
p1 = immigration_data.plot.scatter(x = 'gdp_2013', y = 'num_Im_2013', title = '2013 GDP per capita vs Number of Immigrants',\
                                   figsize = (16,6), color='orange')

# labels
for i in immigration_data['Region of birth']:
    p1.text(x=immigration_data['gdp_2013'][immigration_data[immigration_data['Region of birth'] == i].index[0]], \
            y=immigration_data['num_Im_2013'][immigration_data[immigration_data['Region of birth'] == i].index[0]]+0.3, \
            s=immigration_data['Abbreviation'][immigration_data[immigration_data['Region of birth'] == i].index[0]])
    
# regression line
d = np.polyfit(immigration_data['gdp_2013'],immigration_data['num_Im_2013'],1)
f = np.poly1d(d)
immigration_data.insert(6,'reg_2013',f(immigration_data['gdp_2013']))
immigration_data.plot(x='gdp_2013', y='reg_2013',color='Red', ax=p1)
p1.set_xlabel('GDP per capita')
p1.set_ylabel('Number of Immigrants')
    
# plot 2014
p2 = immigration_data.plot.scatter(x = 'gdp_2014', y = 'num_Im_2014', title = '2014 GDP per capita vs Number of Immigrants',\
                                   figsize = (16,6), color='purple')

# labels
for i in immigration_data['Region of birth']:
    p2.text(x=immigration_data['gdp_2014'][immigration_data[immigration_data['Region of birth'] == i].index[0]], \
            y=immigration_data['num_Im_2014'][immigration_data[immigration_data['Region of birth'] == i].index[0]]+0.3, \
            s=immigration_data['Abbreviation'][immigration_data[immigration_data['Region of birth'] == i].index[0]])

# regression line
d = np.polyfit(immigration_data['gdp_2014'],immigration_data['num_Im_2014'],1)
f = np.poly1d(d)
immigration_data.insert(6,'reg_2014',f(immigration_data['gdp_2014']))
immigration_data.plot(x='gdp_2014', y='reg_2014',color='Red', ax=p2)
p2.set_xlabel('GDP per capita')
p2.set_ylabel('Number of Immigrants')
    
# plot 2015
p3 = immigration_data.plot.scatter(x = 'gdp_2015', y = 'num_Im_2015', title = '2015 GDP per capita vs Number of Immigrants',\
                                   figsize = (16,6), color='blue')

# label
for i in immigration_data['Region of birth']:
    p3.text(x=immigration_data['gdp_2015'][immigration_data[immigration_data['Region of birth'] == i].index[0]], \
            y=immigration_data['num_Im_2015'][immigration_data[immigration_data['Region of birth'] == i].index[0]]+0.3, \
            s=immigration_data['Abbreviation'][immigration_data[immigration_data['Region of birth'] == i].index[0]])

# regression line
d = np.polyfit(immigration_data['gdp_2015'],immigration_data['num_Im_2015'],1)
f = np.poly1d(d)
immigration_data.insert(6,'reg_2015',f(immigration_data['gdp_2015']))
immigration_data.plot(x='gdp_2015', y='reg_2015',color='Red', ax=p3)
p3.set_xlabel('GDP per capita')
p3.set_ylabel('Number of Immigrants')
# Out:
# <AxesSubplot:title={'center':'2015 GDP per capita vs Number of Immigrants'}, xlabel='gdp_2015', ylabel='Number of Immigrants'>

# %% [markdown]
# An alternative to using Pandas and NumPy to make the scatter plots would be using Seaborn. Plotting a scatter plot on Seaborn automatically plots the regression line for you. We chose Pandas and NumPy because we had more experience with it and we knew how to change the colors on the plots.

# %% [markdown]
# ### Initial Thoughts from Plots
# In each of the three plots, we can see that that for the regression line, the number of immigrants decreases as the GDP of countries increases. Based off of this, we think there could be a correlation between GDP per capita of a country and the number of immigrants from that country to the US, but we cannot be certain until we perform hypothesis testing.
#
# Something else to note is there are two clear outliers in Mexico and Qatar. Mexico looks to be a country with low GDP per capita and a lot of immigrants coming to the US, while Qatar has a high GDP per capita with not many immigrants coming to the US.

# %% [markdown]
# ## Hypothesis Testing
# Hypothesis testing is where tests are used to compare a hypothesis to a null hypothesis. A null hypothesis is that there is no significant correlation and it is rejected if its probability is below a standard level (0.05). For our situation, the null hypothesis would be there is no correlation between a country's GDP per capita and the number of immigrants the U.S. gets from it, i.e. people immigrate to the U.S. despiite the economic status of their country of origin. The alternative hypothesis (alternative to the null hypothesis) would be there is a correlation between the GDP per capita of a country and the amount of U.S. immigrants from there, i.e. citizens from less economically developed countries are more likely to immigrate to the U.S.
#
# To test this we will run linear regression line tests on our data.

# %% [markdown]
# ### 2013

# %%
# test for 2013
y = immigration_data['gdp_2013']
x = sm.add_constant(immigration_data[['num_Im_2013']])
lm = sm.OLS(y,x,missing='drop',hasconst = False).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               gdp_2013   R-squared (uncentered):                   0.453
# Model:                            OLS   Adj. R-squared (uncentered):              0.446
# Method:                 Least Squares   F-statistic:                              66.98
# Date:                Mon, 17 May 2021   Prob (F-statistic):                    6.31e-22
# Time:                        15:06:48   Log-Likelihood:                         -1852.2
# No. Observations:                 164   AIC:                                      3708.
# Df Residuals:                     162   BIC:                                      3715.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.834e+04   1647.340     11.130      0.000    1.51e+04    2.16e+04
# num_Im_2013    -0.1290      0.106     -1.222      0.223      -0.338       0.079
# ==============================================================================
# Omnibus:                      129.622   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1528.948
# Skew:                           2.825   Prob(JB):                         0.00
# Kurtosis:                      16.850   Cond. No.                     1.68e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.68e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 2014

# %%
# test for 2014
y = immigration_data['gdp_2014']
x = sm.add_constant(immigration_data[['num_Im_2014']])
lm = sm.OLS(y,x,missing='drop',hasconst = False).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               gdp_2014   R-squared (uncentered):                   0.456
# Model:                            OLS   Adj. R-squared (uncentered):              0.449
# Method:                 Least Squares   F-statistic:                              67.95
# Date:                Mon, 17 May 2021   Prob (F-statistic):                    3.73e-22
# Time:                        15:06:48   Log-Likelihood:                         -1853.5
# No. Observations:                 164   AIC:                                      3711.
# Df Residuals:                     162   BIC:                                      3717.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.864e+04   1658.610     11.238      0.000    1.54e+04    2.19e+04
# num_Im_2014    -0.1350      0.103     -1.314      0.191      -0.338       0.068
# ==============================================================================
# Omnibus:                      128.344   Durbin-Watson:                   1.863
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1483.314
# Skew:                           2.794   Prob(JB):                         0.00
# Kurtosis:                      16.633   Cond. No.                     1.74e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.74e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### 2015

# %%
# test for 2015
y = immigration_data['gdp_2015']
x = sm.add_constant(immigration_data[['num_Im_2015']])
lm = sm.OLS(y,x,missing='drop',hasconst = False).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               gdp_2015   R-squared (uncentered):                   0.457
# Model:                            OLS   Adj. R-squared (uncentered):              0.451
# Method:                 Least Squares   F-statistic:                              68.27
# Date:                Mon, 17 May 2021   Prob (F-statistic):                    3.13e-22
# Time:                        15:06:48   Log-Likelihood:                         -1854.8
# No. Observations:                 164   AIC:                                      3714.
# Df Residuals:                     162   BIC:                                      3720.
# Df Model:                           2
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.876e+04   1661.768     11.287      0.000    1.55e+04     2.2e+04
# num_Im_2015    -0.1154      0.095     -1.210      0.228      -0.304       0.073
# ==============================================================================
# Omnibus:                      127.589   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1455.641
# Skew:                           2.776   Prob(JB):                         0.00
# Kurtosis:                      16.498   Cond. No.                     1.87e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.87e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# The result of all of our linear regression line tests gives p-values all greater than the standard alpha of 0.05, meaning that we are unable to reject the null hypothesis. Given these results, we can infer that economic opprotunity in an immigrants person of origin does not influence their decision to immigrate to the U.S. as much as previously expected.

# %% [markdown]
# ## Insights and Final Thoughts

# %% [markdown]
# ### Recap
# From this tutorial, we wanted to learn about whether there is a correlation between the wealth of certain countries and the number of immigrants the United States receive from those countries. We began by collecting data from a couple different sources and organizing the data in a structure that would be easy to manipute. Then, we plotted the data and performed some hypothesis testing to see whether or not there is a correlation between GDP per capita and number of immigrants to the US. Let's try to put this all together now.

# %% [markdown]
# ### Conclusion
# When first started this project, we wanted to see if economic opportunity was a major influence for immigration to the United States. We decided to do this by collecting data on the national origins of immigrants to the United States and the GDP per capita and running a linear regression test to see if there was a significant correlation between the two. We also decided to use several years so that way we would have multiple samples and don't base our conclusion on just one year of data.
#
# When we plotted the data and fit a linear regression line, we saw that there was some negative correlation between the two fields. However, when we ran the significance test we saw that there was no significant correlation between GDP per capita and the amount of immigrants the U.S. gets from each country.

# %% [markdown]
# ### Things to Consider
# If you can remember, we removed some countries from the data sets at the beginning. We did this because the two sets did not have the same countries, and it was really difficult finding sets with similar ways of organizing their data. Something to consider is there is a chance those countries could reveal something we did not account for, or at the very least, just provide more data to work with. We could have also included a bigger range of years, which could provide more context to what was happening around the world in terms of immigration during certain periods.

# %% [markdown]
# ## Additional Resources
# Of course, this tutorial is only meant to serve as a launching pad. If you would like to learn more, please check out the following links!
#
# **Articles**<br>
# * We read this really interesting article from [FiveThirtyEight](https://fivethirtyeight.com/features/what-the-fox-knows/) at the beginning of the semester and if you want to learn more about Data Science, it would be a great place to start
# * For more statistics on US immigrants read this article on [Key findings about U.S. immigrants](https://www.pewresearch.org/fact-tank/2020/08/20/key-findings-about-u-s-immigrants/)
# * For more information on immigrants around the world, visit [this article](https://www.weforum.org/agenda/2019/03/which-countries-have-the-most-immigrants-51048ff1f9/)
# * [The UN](https://www.un.org/en/development/desa/population/migration/data/index.asp) is also a great place to find immigration data
#
# **More Data**<br>
# * GDP data from [World Bank](https://data.worldbank.org/indicator/NY.GDP.MKTP.CD?end=2019&start=1960&view=chart
# )
#
# **Other possible factors to test with immigration rates**
# * Human development index data
# * Happiness index
